# %%
#ejercicio1
print("hola mundo!")
# Out:
# hola mundo!

# %%
#Ejercicio2
mensaje="hola mundo!"
print(mensaje)
# Out:
# hola mundo!

# %%
#Ejercicio3
nombre = input("ingresa tu nombre: ")
print("¡Hola " + nombre + "!")
# Out:
# ingresa tu nombre: Rosa
# ¡Hola Rosa!

# %%
#Ejercicio4
print(((3 + 2) / (2 * 5)) ** 2)
# Out:
# 0.25

# %%
#Ejercicio5 
horas = float(input("Ingresa horas de trabajo: "))
coste = float(input("Ingresa el cobro por hora: "))
paga = horas * coste
print("Tu paga es", paga)
# Out:
# Ingresa horas de trabajo: 5
# Ingresa el cobro por hora: 250
# Tu paga es 1250.0

# %%
#Ejercicio6
n = int(input("Ingresa un número entero: "))
suma = n * (n + 1) / 2
print("La suma de los primeros números enteros desde 1 hasta " + str(n) + " es " + str(suma))
# Out:
# Ingresa un número entero: 3
# La suma de los primeros números enteros desde 1 hasta 3 es 6.0
